# %%
from src import *

file_name = 'naive_siamese_model_George'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_naive.npz', xmin=0, xmax=1, ymin=0, ymax=60)

# %%
from src import *

file_name = 'pretrained_siamese_model_George'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_pretrained.npz', xmin=0.45, xmax=0.51, ymin=0, ymax=290)
