# %%
from src import *

file_name = 'naive_siamese_model_George_B'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_naive_B.npz', xmin=0.45, xmax=0.55, ymin=0, ymax=25)

# %%
from src import *

file_name = 'pretrained_siamese_model_George_B'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_pretrained_B.npz', xmin=0, xmax=0.5, ymin=0, ymax=140)
