# %%
from src import *

file_name = 'naive_siamese_model_Isaac'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=True, data_path=r'gross_scores_naive_Isaac.npz', xmin=0, xmax=1, ymin=0, ymax=300)
# Out:
# ...
# 100%|██████████| 500/500 [07:20<00:00,  1.13it/s]

# %%
from src import *

file_name = 'transfered_siamese_model_Isaac'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=True, data_path=r'gross_scores_pretrained_Isaac.npz', xmin=0, xmax=1, ymin=0, ymax=300, n_bins=50)
# Out:
# ...
# 100%|██████████| 500/500 [06:34<00:00,  1.27it/s]

# %%
from src import *

file_name = 'naive_siamese_model_George_B'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_naive_B.npz', xmin=0.45, xmax=0.55, ymin=0, ymax=50, n_bins=20)

# %%
from src import *

file_name = 'pretrained_siamese_model_George_B'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_pretrained_B.npz', xmin=0.3, xmax=0.5, ymin=0, ymax=200, n_bins=30)

# %%
from src import *

file_name = 'naive_siamese_model_George_C'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_naive_C.npz', xmin=0.45, xmax=0.55, ymin=0, ymax=25)

# %%
from src import *

file_name = 'pretrained_siamese_model_George_C'

model = make_siamese_model(make_embedding())
model.load_weights(os.path.join(SAVED_MODEL_PATH, f"{file_name}.h5"))
gross_scores_positive, gross_scores_negative = get_histogram_scores(model, max_harvest=500, force_computation=False, data_path=r'gross_scores_pretrained_C.npz', xmin=0.45, xmax=0.55, ymin=0, ymax=35)

# %%
from src import *

empty_folder(VANC_PATH)
data_augment_from_folder(ANC_PATH, VANC_PATH, data_augmentation_factor=20)

maxquery = 100

w = 10
h = 10
fig = plt.figure(figsize=(8, 8))
fig.tight_layout()
columns = 2
rows = 3
for i in range(1, columns*rows +1):
    paths = os.path.join(VANC_PATH, os.listdir(VANC_PATH)[i])
    img = np.array(preprocess(paths))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
# Out:
# Preparing data augmentation from data\anchor to data\var_anchor.
# ...
# 100%|██████████| 1/1 [00:00<00:00,  7.96it/s]
# Successfully generated 20 new images through data augmentation.
